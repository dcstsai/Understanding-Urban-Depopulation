# %% [markdown]
# ### 90803 Data Cleaning and Question Definition
# ### Data Cleaning: 2020 Elections Data
#
# **Team 14**
#
# Chi-Shiun Tsai & Colton Lapp

# %% [markdown]
# This notebook is used for cleaning the 2020 general election from MIT Election Data and Science Lab.

# %% [markdown]
# ### 0. Impoting libraries

# %%
import glob
import numpy as np
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### 1. Reading datasets

# %%
df = pd.read_csv('../data/2020-all-states-local-precinct-general.csv', low_memory=False)
df.sample(25)
# Out:
#                                   precinct  \
# 35376                  CHRIST UN METHODIST
# 441066   77_77 - L.A. AINGER MIDDLE SCHOOL
# 1090698                        OSRB 81-120
# 619489                                V130
# 290125                                 510
# 1338709                 NORTH CHARLESTON 1
# 1263893                         ISSAQUEENA
# 1082958                          OSAP 1-40
# 89514                 GRAND BAY MIDDLE SCH
# 1330466                   BELVEDERE NO. 74
# 1243620                       NEWPORT 2104
# 211650                          7213201221
# 185246      PREC 2160 - JEFFERSON COUNTY C
# 1024281                               017A
# 471609                                05A1
# 618624                                F186
# 760981                          PRECINCT 3
# 8319                     ROSALIE COMM CTR_
# 498005                    LOST MOUNTAIN 01
# 577266                               OAK 3
# 1393369                       CHARLESTON 5
# 1123715                        ENGLEWOOD-I
# 856891                                PR23
# 748704                               07-10
# 710814                    RIVERVIEW SCHOOL
#
#                                                     office party_detailed  \
# 35376                             COUNTY COMMISSION MEMBER     REPUBLICAN
# 441066                                             SHERIFF            NaN
# 1090698  WAKE SOIL AND WATER CONSERVATION DISTRICT SUPE...    NONPARTISAN
# 619489                                      SOIL AND WATER            NaN
# 290125                                     COURT OF APPEAL    NONPARTISAN
# 1338709                                       SCHOOL BOARD    NONPARTISAN
# 1263893                               CITY COUNCIL CLEMSON    NONPARTISAN
# 1082958  WAKE SOIL AND WATER CONSERVATION DISTRICT SUPE...    NONPARTISAN
# 89514                                     COUNTY CONSTABLE            NaN
# 1330466                       REGISTER OF MESNE CONVEYANCE    NONPARTISAN
# 1243620                         SCHOOL COMMITTEE - NEWPORT    NONPARTISAN
# 211650                REGENT OF THE UNIVERSITY OF COLORADO       DEMOCRAT
# 185246                                        TAX ASSESSOR            NaN
# 1024281  UNION SOIL AND WATER CONSERVATION DISTRICT SUP...    NONPARTISAN
# 471609                        ATLANTA HOMESTEAD EXEMPTION             NaN
# 618624                                      SOIL AND WATER            NaN
# 760981                   EUREKA COUNTY TELEVISION DISTRICT     REPUBLICAN
# 8319                      COUNTY BOARD OF EDUCATION MEMBER            NaN
# 498005   COBB COUNTY SPECIAL PURPOSE LOCAL OPTION SALES...            NaN
# 577266   SUNDAY ON-PREMISE ALCOHOL CONSUMPTION STARTING...            NaN
# 1393369                                          SOLICITOR    NONPARTISAN
# 1123715    COUNTY COMMISSIONER: TERM COMMENCING 01/03/2021     REPUBLICAN
# 856891                                DISTRICT COURT JUDGE     REPUBLICAN
# 748704                              RETENTION COUNTY COURT    NONPARTISAN
# 710814                  COUNTY CLERK OF THE DISTRICT COURT    NONPARTISAN
#
#         party_simplified                mode  votes county_name  county_fips  \
# 35376         REPUBLICAN               TOTAL      0      SHELBY       1117.0
# 441066               NaN               TOTAL    138   CHARLOTTE      12015.0
# 1090698      NONPARTISAN    ABSENTEE BY MAIL      0        WAKE      37183.0
# 619489               NaN               TOTAL    116   JEFFERSON      21111.0
# 290125       NONPARTISAN               TOTAL   1695       DUVAL      12031.0
# 1338709      NONPARTISAN  IN PERSON ABSENTEE     42  CHARLESTON      45019.0
# 1263893      NONPARTISAN        ELECTION DAY     44     PICKENS      45077.0
# 1082958      NONPARTISAN    ABSENTEE BY MAIL      0        WAKE      37183.0
# 89514                NaN               TOTAL      0      MOBILE       1097.0
# 1330466      NONPARTISAN        ELECTION DAY      1       AIKEN      45003.0
# 1243620      NONPARTISAN        MAIL BALLOTS    153     NEWPORT      44005.0
# 211650          DEMOCRAT               TOTAL    304       ADAMS       8001.0
# 185246               NaN               TOTAL      0   JEFFERSON       1073.0
# 1024281      NONPARTISAN         PROVISIONAL      0       UNION      37179.0
# 471609               NaN        ELECTION DAY     24      FULTON      13121.0
# 618624               NaN               TOTAL    532   JEFFERSON      21111.0
# 760981        REPUBLICAN               TOTAL    124      EUREKA      32011.0
# 8319                 NaN               TOTAL      5     JACKSON       1071.0
# 498005               NaN        ELECTION DAY    169        COBB      13067.0
# 577266               NaN         PROVISIONAL      5     CLAYTON      13063.0
# 1393369      NONPARTISAN  IN PERSON ABSENTEE      0  CHARLESTON      45019.0
# 1123715       REPUBLICAN               TOTAL    268  MONTGOMERY      39113.0
# 856891        REPUBLICAN        ELECTION DAY    513     HARNETT      37085.0
# 748704       NONPARTISAN               TOTAL    810     DOUGLAS      31055.0
# 710814       NONPARTISAN               TOTAL     18      CUSTER      30017.0
#
#         jurisdiction_name  jurisdiction_fips  ... stage           state  \
# 35376              SHELBY               1117  ...   GEN         ALABAMA
# 441066          CHARLOTTE              12015  ...   GEN         FLORIDA
# 1090698              WAKE              37183  ...   GEN  NORTH CAROLINA
# 619489          JEFFERSON              21111  ...   GEN        KENTUCKY
# 290125              DUVAL              12031  ...   GEN         FLORIDA
# 1338709        CHARLESTON              45019  ...   GEN  SOUTH CAROLINA
# 1263893           PICKENS              45077  ...   GEN  SOUTH CAROLINA
# 1082958              WAKE              37183  ...   GEN  NORTH CAROLINA
# 89514              MOBILE               1097  ...   GEN         ALABAMA
# 1330466             AIKEN              45003  ...   GEN  SOUTH CAROLINA
# 1243620           NEWPORT         4400549960  ...   GEN    RHODE ISLAND
# 211650              ADAMS               8001  ...   GEN        COLORADO
# 185246          JEFFERSON               1073  ...   GEN         ALABAMA
# 1024281             UNION              37179  ...   GEN  NORTH CAROLINA
# 471609             FULTON              13121  ...   GEN         GEORGIA
# 618624          JEFFERSON              21111  ...   GEN        KENTUCKY
# 760981             EUREKA              32011  ...   GEN          NEVADA
# 8319              JACKSON               1071  ...   GEN         ALABAMA
# 498005               COBB              13067  ...   GEN         GEORGIA
# 577266            CLAYTON              13063  ...   GEN         GEORGIA
# 1393369        CHARLESTON              45019  ...   GEN  SOUTH CAROLINA
# 1123715        MONTGOMERY              39113  ...   GEN            OHIO
# 856891            HARNETT              37085  ...   GEN  NORTH CAROLINA
# 748704            DOUGLAS              31055  ...   GEN        NEBRASKA
# 710814             CUSTER              30017  ...   GEN         MONTANA
#
#          special writein  state_po state_fips state_cen  state_ic        date  \
# 35376      False   False        AL          1        63        41  2020-11-03
# 441066     False   False        FL         12        59        43  2020-11-03
# 1090698    False    True        NC         37        56        47  2020-11-03
# 619489     False   False        KY         21        61        51  2020-11-03
# 290125     False   False        FL         12        59        43  2020-11-03
# 1338709    False   False        SC         45        57        48  2020-11-03
# 1263893    False   False        SC         45        57        48  2020-11-03
# 1082958    False    True        NC         37        56        47  2020-11-03
# 89514      False   False        AL          1        63        41  2020-11-03
# 1330466    False   False        SC         45        57        48  2020-11-03
# 1243620    False   False        RI         44        15         5  2020-11-03
# 211650     False   False        CO          8        84        62  2020-11-03
# 185246     False    True        AL          1        63        41  2020-11-03
# 1024281    False    True        NC         37        56        47  2020-11-03
# 471609      True   False        GA         13        58        44  2020-11-03
# 618624     False   False        KY         21        61        51  2020-11-03
# 760981     False   False        NV         32        88        65  2020-11-03
# 8319       False    True        AL          1        63        41  2020-11-03
# 498005      True   False        GA         13        58        44  2020-11-03
# 577266      True   False        GA         13        58        44  2020-11-03
# 1393369    False   False        SC         45        57        48  2020-11-03
# 1123715    False   False        OH         39        31        24  2020-11-03
# 856891     False   False        NC         37        56        47  2020-11-03
# 748704     False   False        NE         31        46        35  2020-11-03
# 710814     False   False        MT         30        81        64  2020-11-03
#
#         readme_check
# 35376          False
# 441066         False
# 1090698        False
# 619489         False
# 290125         False
# 1338709        False
# 1263893        False
# 1082958        False
# 89514          False
# 1330466        False
# 1243620        False
# 211650         False
# 185246         False
# 1024281        False
# 471609         False
# 618624         False
# 760981         False
# 8319           False
# 498005         False
# 577266         False
# 1393369        False
# 1123715         True
# 856891         False
# 748704         False
# 710814         False
#
# [25 rows x 25 columns]

# %% [markdown]
# ### 2. Data cleaning

# %%
# Subset to only columns we want
df = df[['year', 'state', 'precinct', 'office', 'party_simplified', 'votes']]
df
# Out:
#          year    state               precinct               office  \
# 0        2020  ALABAMA  BELLAMY COMMUNITY CTR    3 MILL SCHOOL TAX
# 1        2020  ALABAMA  BELLAMY COMMUNITY CTR    3 MILL SCHOOL TAX
# 2        2020  ALABAMA  BELLAMY COMMUNITY CTR    3 MILL SCHOOL TAX
# 3        2020  ALABAMA  BELLAMY COMMUNITY CTR    3 MILL SCHOOL TAX
# 4        2020  ALABAMA           BOYD TRAILER    3 MILL SCHOOL TAX
# ...       ...      ...                    ...                  ...
# 1485059  2020  WYOMING                    9-1  CIRCUIT COURT JUDGE
# 1485060  2020  WYOMING                    9-1  CIRCUIT COURT JUDGE
# 1485061  2020  WYOMING                    9-1  CIRCUIT COURT JUDGE
# 1485062  2020  WYOMING                    9-1  CIRCUIT COURT JUDGE
# 1485063  2020  WYOMING                    9-1  CIRCUIT COURT JUDGE
#
#         party_simplified  votes
# 0                    NaN      0
# 1                    NaN     25
# 2            NONPARTISAN     62
# 3            NONPARTISAN    171
# 4                    NaN      0
# ...                  ...    ...
# 1485059      NONPARTISAN    272
# 1485060      NONPARTISAN     64
# 1485061      NONPARTISAN    256
# 1485062      NONPARTISAN     56
# 1485063      NONPARTISAN    282
#
# [1485064 rows x 6 columns]

# %%
# Group by year, state, office, and party, and sum the votes
df.groupby(['year', 'state', 'office', 'party_simplified']).sum()
# Out:
#                                                                                      votes
# year state     office                                             party_simplified
# 2020 ALABAMA   3 MILL SCHOOL TAX                                  NONPARTISAN         5148
#                5 MILL SCHOOL TAX                                  NONPARTISAN         5189
#                ASSISTANT TAX ASSESSOR BESSEMER DIVISION OF JEF... DEMOCRAT           44153
#                                                                   REPUBLICAN         35314
#                ASSISTANT TAX COLLECTOR BESSEMER DIVISION OF JE... DEMOCRAT           44063
# ...                                                                                    ...
#      WISCONSIN WAUSHARA COUNTY DISTRICT ATTORNEY                  DEMOCRAT            3955
#                                                                   REPUBLICAN          9188
#                WINNEBAGO COUNTY DISTRICT ATTORNEY                 REPUBLICAN         70331
#                WOOD COUNTY DISTRICT ATTORNEY                      OTHER              29128
#      WYOMING   CIRCUIT COURT JUDGE                                NONPARTISAN       402938
#
# [2689 rows x 1 columns]

# %%
# Check for missing values
df.isnull().sum(axis=0)
# Out:
# year                     0
# state                    0
# precinct                 0
# office                   0
# party_simplified    357354
# votes                    0
# dtype: int64

# %%
df['party_simplified'].unique()
# Out:
# array([nan, 'NONPARTISAN', 'DEMOCRAT', 'REPUBLICAN', 'OTHER',
#        'LIBERTARIAN'], dtype=object)

# %%
# Fill missing values with NONE
df['party_simplified'] = df['party_simplified'].fillna('NONE')
df['party_simplified'].unique()
# Out:
# array(['NONE', 'NONPARTISAN', 'DEMOCRAT', 'REPUBLICAN', 'OTHER',
#        'LIBERTARIAN'], dtype=object)

# %%
# Check for missing values again to make sure we got them all
df.isnull().sum(axis=0)
# Out:
# year                0
# state               0
# precinct            0
# office              0
# party_simplified    0
# votes               0
# dtype: int64

# %% [markdown]
# ### 3. Save cleaned dataset

# %%
df_cleaned = df.groupby(['year', 'state', 'office', 'party_simplified']).sum().reset_index()

# %%
df_cleaned.head(10)
# Out:
#    year    state                                             office  \
# 0  2020  ALABAMA                                  3 MILL SCHOOL TAX
# 1  2020  ALABAMA                                  3 MILL SCHOOL TAX
# 2  2020  ALABAMA                                  5 MILL SCHOOL TAX
# 3  2020  ALABAMA                                  5 MILL SCHOOL TAX
# 4  2020  ALABAMA  ASSISTANT TAX ASSESSOR BESSEMER DIVISION OF JE...
# 5  2020  ALABAMA  ASSISTANT TAX ASSESSOR BESSEMER DIVISION OF JE...
# 6  2020  ALABAMA  ASSISTANT TAX ASSESSOR BESSEMER DIVISION OF JE...
# 7  2020  ALABAMA  ASSISTANT TAX COLLECTOR BESSEMER DIVISION OF J...
# 8  2020  ALABAMA  ASSISTANT TAX COLLECTOR BESSEMER DIVISION OF J...
# 9  2020  ALABAMA  ASSISTANT TAX COLLECTOR BESSEMER DIVISION OF J...
#
#   party_simplified  votes
# 0             NONE   1176
# 1      NONPARTISAN   5148
# 2             NONE   1135
# 3      NONPARTISAN   5189
# 4         DEMOCRAT  44153
# 5             NONE   1707
# 6       REPUBLICAN  35314
# 7         DEMOCRAT  44063
# 8             NONE   1811
# 9       REPUBLICAN  35299

# %%
df_cleaned.to_csv('../data/data_cleaned/2020-all-states-local-precinct-general-cleaned.csv', index=False)

# %% [markdown]
# ### References
#
# - MIT election web: https://electionlab.mit.edu/
# - Codebook: https://github.com/MEDSL/2020-elections-official/blob/main/2020-precincts-codebook.md
